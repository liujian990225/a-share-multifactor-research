# %% [markdown]
# # 01 数据读取与清洗
#
# 运行 demo 数据或替换为真实 CSV 数据，检查字段和缺失值。

# %%
from mf_strategy.config import load_config
from mf_strategy.data_loader import load_market_data

config = load_config('../configs/config_demo.yaml')
data = load_market_data(config)
data.prices.head()
